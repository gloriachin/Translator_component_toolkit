# %%
#!pip install TCT

from TCT import name_resolver
from TCT import translator_metakg
from TCT import translator_kpinfo
from TCT import TCT
from TCT import TCT_neighborhood_finder

import matplotlib.pyplot as plt
import requests
from TCT import get_translator_resources, query_TCT_pathfinder

# %%
APInames, metaKG, Translator_KP_info= translator_metakg.load_translator_resources(use_new_metakg_url=True)

All_predicates = list(set(metaKG['Predicate']))
All_categories = list((set(list(set(metaKG['Subject']))+list(set(metaKG['Object'])))))
API_withMetaKG = list(set(metaKG['API']))

API_predicates = {}
for api in API_withMetaKG:
    API_predicates[api] = list(set(metaKG[metaKG['API'] == api]['Predicate']))
# Out:
# Skipping server without x-maturity: {'url': '/sipr'}
# Skipping server without x-maturity: {'description': 'Local dev', 'url': 'http://127.0.0.1:5001'}

# %%
url = 'https://amlkg.systemsbiology.org/AMLkg/meta_knowledge_graph'
response = requests.get(url, verify=False)
data = response.json()

for i in range(len(data["edges"])):
    APInames, metaKG = translator_metakg.add_new_API_for_query(APInames, metaKG, "AMLKG", "https://amlkg.systemsbiology.org/AMLkg/query/", data["edges"][i]['predicate'], data["edges"][i]['subject'], data["edges"][i]['object'])

API_withMetaKG = list(set(metaKG['API']))
for api in API_withMetaKG:
    API_predicates[api] = list(set(metaKG[metaKG['API'] == api]['Predicate']))
# Out:
# /opt/miniconda3/envs/my-rdkit-env/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'amlkg.systemsbiology.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import networkx as nx
selected_KGs = ['AMLKG']

metaKG_sele = metaKG[metaKG['API'].isin(selected_KGs)]

# build a multigraph to capture all edges (including duplicates) and their predicates
G = nx.MultiGraph()
for _, row in metaKG_sele.iterrows():
        G.add_edge(row['Subject'], row['Object'], predicate=row['Predicate'])

# layout and draw nodes + edges
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G, k=0.5, iterations=20)
nx.draw(G, pos,
                with_labels=True,
                node_size=50,
                font_size=12,
                font_color='black',
                node_color='blue',
                edge_color='gray')

# draw edge labels
edge_labels = nx.get_edge_attributes(G, 'predicate')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)
plt.title('Interaction Graph of Subjects and Objects in metaKG')
plt.show()

# %%
# select a list of APIs to use and a list of predicates to use


selected_APIlist = ['AMLKG',
                    'Retriever',
                    'Clinical Trials KP - TRAPI 1.5.0',
                    'Drug Approvals KP - TRAPI 1.5.0',
                    'Genetics Data Provider for NCATS Biomedical Translator Reasoners',
                    #'Microbiome KP - TRAPI 1.5.0',
                    #'MolePro',
                    #'COHD TRAPI',
                    'RTX KG2 - TRAPI 1.5.0',
                    #'Text Mined Cooccurrence API',
                    'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0',
                    'CATRAX Pharmacogenomics KP - TRAPI 1.5.0',
                    ]

if len(selected_APIlist) == 0:
    select_APIs = APInames
else:
    select_APIs = {k: APInames[k] for k in selected_APIlist if k in APInames}

selected_metaKG = metaKG[metaKG['API'].isin(select_APIs.keys())]
print(select_APIs)
print(selected_metaKG.shape)
# Out:
# {'AMLKG': 'https://amlkg.systemsbiology.org/AMLkg/query/', 'Retriever': 'https://retriever.ci.transltr.io/query/', 'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query', 'Drug Approvals KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/dakp/query', 'Genetics Data Provider for NCATS Biomedical Translator Reasoners': 'https://genetics-kp.transltr.io/genetics_provider/trapi/v1.5/query/', 'RTX KG2 - TRAPI 1.5.0': 'https://kg2cploverdb.ci.transltr.io/kg2c/query', 'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/BigGIM_DrugResponse_PerformancePhase/query', 'CATRAX Pharmacogenomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query'}
# (15090, 5)

# %%
metaKG.loc[metaKG['API'] == 'AMLKG',['API','Predicate','Subject','Object']].drop_duplicates()
# Out:
#          API                                          Predicate  \
# 30172  AMLKG                               biolink:expressed_in
# 30173  AMLKG                                  biolink:regulates
# 30174  AMLKG                                  biolink:regulates
# 30175  AMLKG                                  biolink:regulates
# 30176  AMLKG                                  biolink:regulates
# 30177  AMLKG                                  biolink:regulates
# 30178  AMLKG                                  biolink:regulates
# 30179  AMLKG                                  biolink:regulates
# 30180  AMLKG                                  biolink:regulates
# 30181  AMLKG                                  biolink:regulates
# 30182  AMLKG                                  biolink:regulates
# 30183  AMLKG                                  biolink:regulates
# 30184  AMLKG                                  biolink:regulates
# 30185  AMLKG                                  biolink:regulates
# 30186  AMLKG                                  biolink:regulates
# 30187  AMLKG                                  biolink:regulates
# 30188  AMLKG                                  biolink:regulates
# 30189  AMLKG                                  biolink:regulates
# 30190  AMLKG                                  biolink:regulates
# 30191  AMLKG                                  biolink:regulates
# 30192  AMLKG                                  biolink:regulates
# 30193  AMLKG                            biolink:in_complex_with
# 30194  AMLKG                            biolink:in_complex_with
# 30195  AMLKG                                  biolink:regulates
# 30196  AMLKG                            biolink:in_complex_with
# 30197  AMLKG                                  biolink:regulates
# 30198  AMLKG                                  biolink:regulates
# 30199  AMLKG                            biolink:in_complex_with
# 30200  AMLKG                                  biolink:regulates
# 30201  AMLKG                                  biolink:regulates
# 30202  AMLKG                                  biolink:regulates
# 30203  AMLKG                                  biolink:regulates
# 30204  AMLKG                            biolink:in_complex_with
# 30205  AMLKG                                  biolink:regulates
# 30206  AMLKG                                  biolink:regulates
# 30207  AMLKG                                  biolink:regulates
# 30208  AMLKG                                  biolink:regulates
# 30209  AMLKG                                  biolink:regulates
# 30210  AMLKG                                  biolink:regulates
# 30211  AMLKG                                  biolink:regulates
# 30212  AMLKG                                  biolink:regulates
# 30213  AMLKG             biolink:associated_with_sensitivity_to
# 30214  AMLKG              biolink:associated_with_resistance_to
# 30215  AMLKG  biolink:GeneToDiseaseOrPhenotypicFeatureAssoci...
# 30216  AMLKG                                     biolink:treats
# 30217  AMLKG                                biolink:subclass_of
#
#                              Subject                         Object
# 30172                   biolink:Gene                   biolink:Cell
# 30173                   biolink:Gene                   biolink:Gene
# 30174  biolink:MacromolecularComplex                   biolink:Gene
# 30175  biolink:MacromolecularComplex      biolink:PhenotypicFeature
# 30176         biolink:ChemicalEntity                   biolink:Gene
# 30177                biolink:Protein                   biolink:Gene
# 30178                   biolink:Gene  biolink:MacromolecularComplex
# 30179          biolink:SmallMolecule                   biolink:Gene
# 30180          biolink:SmallMolecule          biolink:SmallMolecule
# 30181          biolink:SmallMolecule          biolink:ProteinFamily
# 30182          biolink:ProteinFamily                   biolink:Gene
# 30183   biolink:EnvironmentalProcess                   biolink:Gene
# 30184                   biolink:Gene      biolink:PhenotypicFeature
# 30185  biolink:MacromolecularComplex  biolink:MacromolecularComplex
# 30186                   biolink:Gene                biolink:Protein
# 30187          biolink:ProteinFamily          biolink:ProteinFamily
# 30188          biolink:ProteinFamily  biolink:MacromolecularComplex
# 30189         biolink:ChemicalEntity  biolink:MacromolecularComplex
# 30190          biolink:SmallMolecule  biolink:MacromolecularComplex
# 30191  biolink:MacromolecularComplex                biolink:Protein
# 30192  biolink:MacromolecularComplex          biolink:ProteinFamily
# 30193          biolink:ProteinFamily  biolink:MacromolecularComplex
# 30194  biolink:MacromolecularComplex  biolink:MacromolecularComplex
# 30195                biolink:Protein      biolink:PhenotypicFeature
# 30196          biolink:SmallMolecule  biolink:MacromolecularComplex
# 30197         biolink:ChemicalEntity          biolink:ProteinFamily
# 30198               biolink:MicroRNA                   biolink:Gene
# 30199         biolink:ChemicalEntity  biolink:MacromolecularComplex
# 30200          biolink:ProteinFamily      biolink:PhenotypicFeature
# 30201          biolink:SmallMolecule      biolink:PhenotypicFeature
# 30202                   biolink:Drug                   biolink:Gene
# 30203                biolink:Protein  biolink:MacromolecularComplex
# 30204                biolink:Protein  biolink:MacromolecularComplex
# 30205   biolink:Noncoding_RNAProduct                   biolink:Gene
# 30206                biolink:Protein          biolink:ProteinFamily
# 30207         biolink:ChemicalEntity                biolink:Protein
# 30208          biolink:ProteinFamily                biolink:Protein
# 30209   biolink:EnvironmentalProcess          biolink:SmallMolecule
# 30210          biolink:SmallMolecule                biolink:Protein
# 30211               biolink:MicroRNA      biolink:PhenotypicFeature
# 30212               biolink:MicroRNA                biolink:Protein
# 30213                   biolink:Gene                   biolink:Drug
# 30214                   biolink:Gene                   biolink:Drug
# 30215                   biolink:Gene                biolink:Disease
# 30216                   biolink:Drug                biolink:Disease
# 30217                biolink:Disease                biolink:Disease

# %%
#name_resolver.lookup('miR-155', only_taxa='NCBITaxon:9606')
subject_name = 'BCL2'
subject_node = name_resolver.lookup(subject_name, only_taxa='NCBITaxon:9606').curie

subject_category = name_resolver.lookup(subject_name).types
subject_category = ["biolink:Gene", "biolink:Protein"]

object_name = 'acute myeloid leukemia'
object_node = name_resolver.lookup(object_name, biolink_category='biolink:Disease').curie
object_category = name_resolver.lookup(object_name, biolink_category='biolink:Disease').types
object_category = ["biolink:Disease"]

intermediate_categories = [ 'biolink:Drug','biolink:SmallMolecule','biolink:ChemicalSubstance','biolink:Gene','biolink:Protein']

# %%
subject_name = 'venetoclax'
subject_node = name_resolver.lookup(subject_name).curie
subject_node
# Out:
# 'CHEBI:133021'

# %%
print(f"Subject: {subject_name}, CURIE: {subject_node}, Category: {subject_category}")
print(f"Object: {object_name}, CURIE: {object_node}, Category: {object_category}")
# Out:
# Subject: venetoclax, CURIE: CHEBI:133021, Category: ['biolink:Gene', 'biolink:Protein']
# Object: acute myeloid leukemia, CURIE: MONDO:0018874, Category: ['biolink:Disease']

# %%
# test neighborhood finder by adding a new API to the metaKG
finder_result = TCT_neighborhood_finder.neighborhood_finder(
    subject_node,
    # neighbor_categories=['biolink:Drug', 'biolink:SmallMolecule', 'biolink:ChemicalSubstance'],
    # neighbor_categories=['biolink:AnatomicalEntity'],
    neighbor_categories=['biolink:Disease'],
    api_names=select_APIs,
    meta_kg=selected_metaKG,
    api_predicates=API_predicates,
    node_categories=['biolink:Gene'],
)
TCT_neighborhood_finder_result = finder_result.raw
# Out:
# AMLKG: Success!
# Retriever: Success!
# RTX KG2 - TRAPI 1.5.0: Success!

# %%
input_identifiers = subject_node
import datetime
import json
timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
with open('TCT_neighborhood_finder_result_'+input_identifiers.replace(':', '_')+'_'+timestamp+'.json', 'w') as f:
    json.dump(TCT_neighborhood_finder_result, f)

# %%
# test pathfinder by adding a new API to the metaKG
result = query_TCT_pathfinder(start=subject_node,  # e.g. IFNG
                    end=object_node,  # e.g. disease node
                    intermediate_categories=intermediate_categories,
                    api_names=select_APIs,
                    meta_kg=selected_metaKG,
                    api_predicates=API_predicates)
# Out:
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0: Success!
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# AMLKG: Success!
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# Drug Approvals KP - TRAPI 1.5.0: Success!
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Clinical Trials KP - TRAPI 1.5.0: Success!

# %%
# pathfinder already returns parsed results inside a FinderResult
import json
with open(f'TCT_path_finder_result__{subject_node.replace(":", "_")}__{object_node.replace(":", "_")}.json', 'w') as f:
    json.dump(result.to_dict(), f, indent=4)
